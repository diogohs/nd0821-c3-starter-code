# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(r"../data/census_clean.csv", index_col=0)
data.head()
# Out:
#    age         workclass   fnlgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
train, test = train_test_split(data, test_size=0.20, random_state=42)

# %%
test
# Out:
#        age         workclass   fnlgt     education  education-num  \
# 3643    31         State-gov   33308     Assoc-voc             11
# 16036   24       Federal-gov  130534     Bachelors             13
# 9401    60         Local-gov   98350  Some-college             10
# 17903   31           Private  398988  Some-college             10
# 5198    43       Federal-gov  144778     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 8213    22           Private  157332       HS-grad              9
# 24623   49           Private  187454       HS-grad              9
# 5514    43  Self-emp-not-inc  183479       HS-grad              9
# 29810   32         Local-gov  112650       HS-grad              9
# 29036   46       Federal-gov   33794     Bachelors             13
#
#            marital-status       occupation   relationship                race  \
# 3643   Married-civ-spouse     Craft-repair        Husband               White
# 16036       Never-married  Exec-managerial  Not-in-family               White
# 9401   Married-civ-spouse    Other-service        Husband  Asian-Pac-Islander
# 17903       Never-married  Exec-managerial  Not-in-family               White
# 5198        Never-married  Exec-managerial  Not-in-family               White
# ...                   ...              ...            ...                 ...
# 8213        Never-married    Other-service      Own-child               White
# 24623  Married-civ-spouse            Sales        Husband               White
# 5514   Married-civ-spouse     Craft-repair        Husband               White
# 29810  Married-civ-spouse  Protective-serv        Husband               White
# 29036  Married-civ-spouse     Tech-support        Husband               White
#
#           sex  capital-gain  capital-loss  hours-per-week native-country  \
# 3643     Male             0             0              40  United-States
# 16036    Male             0             0              40  United-States
# 9401     Male             0             0              60    Philippines
# 17903    Male             0             0              40  United-States
# 5198     Male             0             0              40  United-States
# ...       ...           ...           ...             ...            ...
# 8213   Female             0             0              35  United-States
# 24623    Male         99999             0              65  United-States
# 5514     Male             0             0              30  United-States
# 29810    Male             0             0              40  United-States
# 29036    Male          3103             0              40  United-States
#
#       salary
# 3643   <=50K
# 16036  <=50K
# 9401   <=50K
# 17903  <=50K
# 5198    >50K
# ...      ...
# 8213   <=50K
# 24623   >50K
# 5514   <=50K
# 29810  <=50K
# 29036   >50K
#
# [6508 rows x 15 columns]
